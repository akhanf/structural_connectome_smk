# %%
#in_csv = 'work/sub-PILOT/connectome_aparcaseg.csv'

in_csv = snakemake.input['connectome']
out_png = snakemake.output[0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
C = np.loadtxt(in_csv)

# %%
#symmetrize C
C = C + C.transpose()

# %%
#plot it
plt.imshow(np.log(C+0.0001))
plt.savefig(out_png)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b3fe3bd07588> in <module>
#       1 #plot it
#       2 plt.imshow(np.log(C+0.0001))
# ----> 3 plt.savefig(out_png)
#
# NameError: name 'out_png' is not defined
